# %%
import numpy as np
import pandas as pd
from scipy import io
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from imblearn.over_sampling import SMOTE

# Load data
y_tr = pd.read_csv('tox21_labels_train.csv.gz', index_col=0, compression="gzip")
y_te = pd.read_csv('tox21_labels_test.csv.gz', index_col=0, compression="gzip")
x_tr_dense = pd.read_csv('tox21_dense_train.csv.gz', index_col=0, compression="gzip").values
x_te_dense = pd.read_csv('tox21_dense_test.csv.gz', index_col=0, compression="gzip").values
x_tr_sparse = io.mmread('tox21_sparse_train.mtx.gz').tocsc()
x_te_sparse = io.mmread('tox21_sparse_test.mtx.gz').tocsc()

# Filter and concatenate dense + sparse features
sparse_col_idx = ((x_tr_sparse > 0).mean(0) > 0.05).A.ravel()
x_tr = np.hstack([x_tr_dense, x_tr_sparse[:, sparse_col_idx].A])
x_te = np.hstack([x_te_dense, x_te_sparse[:, sparse_col_idx].A])

# Standardize features with tanh scaling
scaler = StandardScaler()
x_tr = np.tanh(scaler.fit_transform(x_tr))
x_te = np.tanh(scaler.transform(x_te))

# Create a shared multi-task model architecture
def create_model(input_dim):
    model = Sequential([
        Dense(1024, input_dim=input_dim, kernel_regularizer=l2(1e-5)),
        BatchNormalization(),
        LeakyReLU(alpha=0.2),
        Dropout(0.5),  # Increased dropout to reduce overfitting

        Dense(512, kernel_regularizer=l2(1e-5)),
        BatchNormalization(),
        LeakyReLU(alpha=0.2),
        Dropout(0.4),

        Dense(1, activation='sigmoid')  # Binary output for classification
    ])
    return model

# Early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Train and evaluate the model for each task independently
test_auc_scores = []
models = []  # Store models for later use

for i, target in enumerate(y_tr.columns):
    print(f"\nTraining on assay: {target}")

    # Select valid rows for the current task
    valid_rows = np.isfinite(y_tr[target]).values
    x_target, y_target = x_tr[valid_rows], y_tr[target][valid_rows]

    # Apply SMOTE to handle class imbalance
    smote = SMOTE(random_state=42)
    x_balanced, y_balanced = smote.fit_resample(x_target, y_target)

    # Split into train/validation sets
    x_train, x_val, y_train, y_val = train_test_split(
        x_balanced, y_balanced, test_size=0.2, random_state=42
    )

    # Create and compile a new model
    model = create_model(input_dim=x_tr.shape[1])
    optimizer = Adam(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['AUC'])

    # Train the model
    model.fit(
        x_train, y_train, validation_data=(x_val, y_val),
        epochs=100, batch_size=128,  # Increased batch size
        callbacks=[early_stopping, reduce_lr], verbose=2
    )

    # Store the model
    models.append(model)

    # Evaluate on the test set
    valid_test_rows = np.isfinite(y_te[target]).values
    y_test = y_te[target][valid_test_rows].values
    test_predictions = model.predict(x_te[valid_test_rows]).ravel()
    test_auc = roc_auc_score(y_test, test_predictions)
    test_auc_scores.append(test_auc)

    print(f"{target}: Test AUC = {test_auc:.3f}")

# Calculate and print the average Test AUC score
avg_test_auc = np.mean(test_auc_scores)
print(f"\nAverage Test AUC: {avg_test_auc:.3f}")
# Out:
# Training on assay: NR.AhR
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 94/94 - 12s - 131ms/step - AUC: 0.8717 - loss: 0.5891 - val_AUC: 0.9320 - val_loss: 0.4226 - learning_rate: 0.0100
# Epoch 2/100
# 94/94 - 0s - 4ms/step - AUC: 0.9296 - loss: 0.4234 - val_AUC: 0.9282 - val_loss: 0.4390 - learning_rate: 0.0100
# Epoch 3/100
# 94/94 - 0s - 4ms/step - AUC: 0.9412 - loss: 0.3971 - val_AUC: 0.9488 - val_loss: 0.3955 - learning_rate: 0.0100
# Epoch 4/100
# 94/94 - 1s - 7ms/step - AUC: 0.9501 - loss: 0.3758 - val_AUC: 0.9635 - val_loss: 0.3481 - learning_rate: 0.0100
# Epoch 5/100
# 94/94 - 1s - 6ms/step - AUC: 0.9560 - loss: 0.3621 - val_AUC: 0.9604 - val_loss: 0.3574 - learning_rate: 0.0100
# Epoch 6/100
# 94/94 - 0s - 4ms/step - AUC: 0.9602 - loss: 0.3536 - val_AUC: 0.9689 - val_loss: 0.3486 - learning_rate: 0.0100
# Epoch 7/100
# 94/94 - 1s - 6ms/step - AUC: 0.9640 - loss: 0.3508 - val_AUC: 0.9706 - val_loss: 0.3312 - learning_rate: 0.0100
# Epoch 8/100
# 94/94 - 0s - 4ms/step - AUC: 0.9647 - loss: 0.3534 - val_AUC: 0.9703 - val_loss: 0.3313 - learning_rate: 0.0100
# Epoch 9/100
# 94/94 - 0s - 4ms/step - AUC: 0.9670 - loss: 0.3492 - val_AUC: 0.9702 - val_loss: 0.3399 - learning_rate: 0.0100
# Epoch 10/100
# 94/94 - 1s - 7ms/step - AUC: 0.9680 - loss: 0.3535 - val_AUC: 0.9767 - val_loss: 0.3178 - learning_rate: 0.0100
# Epoch 11/100
# 94/94 - 1s - 7ms/step - AUC: 0.9684 - loss: 0.3562 - val_AUC: 0.9771 - val_loss: 0.3172 - learning_rate: 0.0100
# Epoch 12/100
# 94/94 - 1s - 6ms/step - AUC: 0.9713 - loss: 0.3479 - val_AUC: 0.9773 - val_loss: 0.3246 - learning_rate: 0.0100
# Epoch 13/100
# 94/94 - 1s - 5ms/step - AUC: 0.9702 - loss: 0.3591 - val_AUC: 0.9713 - val_loss: 0.3487 - learning_rate: 0.0100
# Epoch 14/100
# 94/94 - 1s - 6ms/step - AUC: 0.9720 - loss: 0.3511 - val_AUC: 0.9784 - val_loss: 0.3205 - learning_rate: 0.0100
# Epoch 15/100
# 94/94 - 0s - 4ms/step - AUC: 0.9717 - loss: 0.3533 - val_AUC: 0.9730 - val_loss: 0.3477 - learning_rate: 0.0100
# Epoch 16/100
# 94/94 - 0s - 4ms/step - AUC: 0.9730 - loss: 0.3505 - val_AUC: 0.9647 - val_loss: 0.3748 - learning_rate: 0.0100
# Epoch 17/100
# 94/94 - 0s - 4ms/step - AUC: 0.9812 - loss: 0.3073 - val_AUC: 0.9818 - val_loss: 0.2910 - learning_rate: 0.0050
# Epoch 18/100
# 94/94 - 1s - 6ms/step - AUC: 0.9813 - loss: 0.2984 - val_AUC: 0.9794 - val_loss: 0.3129 - learning_rate: 0.0050
# Epoch 19/100
# 94/94 - 1s - 7ms/step - AUC: 0.9836 - loss: 0.2809 - val_AUC: 0.9807 - val_loss: 0.2850 - learning_rate: 0.0050
# Epoch 20/100
# 94/94 - 1s - 6ms/step - AUC: 0.9848 - loss: 0.2724 - val_AUC: 0.9772 - val_loss: 0.2989 - learning_rate: 0.0050
# Epoch 21/100
# 94/94 - 1s - 7ms/step - AUC: 0.9859 - loss: 0.2660 - val_AUC: 0.9835 - val_loss: 0.2762 - learning_rate: 0.0050
# Epoch 22/100
# 94/94 - 1s - 7ms/step - AUC: 0.9846 - loss: 0.2750 - val_AUC: 0.9846 - val_loss: 0.2781 - learning_rate: 0.0050
# Epoch 23/100
# 94/94 - 1s - 7ms/step - AUC: 0.9870 - loss: 0.2583 - val_AUC: 0.9691 - val_loss: 0.3323 - learning_rate: 0.0050
# Epoch 24/100
# 94/94 - 0s - 4ms/step - AUC: 0.9863 - loss: 0.2636 - val_AUC: 0.9816 - val_loss: 0.2825 - learning_rate: 0.0050
# Epoch 25/100
# 94/94 - 0s - 4ms/step - AUC: 0.9866 - loss: 0.2627 - val_AUC: 0.9825 - val_loss: 0.2737 - learning_rate: 0.0050
# Epoch 26/100
# 94/94 - 0s - 4ms/step - AUC: 0.9843 - loss: 0.2738 - val_AUC: 0.9818 - val_loss: 0.2804 - learning_rate: 0.0050
# Epoch 27/100
# 94/94 - 1s - 7ms/step - AUC: 0.9878 - loss: 0.2560 - val_AUC: 0.9863 - val_loss: 0.2482 - learning_rate: 0.0050
# Epoch 28/100
# 94/94 - 1s - 7ms/step - AUC: 0.9877 - loss: 0.2511 - val_AUC: 0.9846 - val_loss: 0.2902 - learning_rate: 0.0050
# Epoch 29/100
# 94/94 - 0s - 4ms/step - AUC: 0.9871 - loss: 0.2529 - val_AUC: 0.9828 - val_loss: 0.2756 - learning_rate: 0.0050
# Epoch 30/100
# 94/94 - 1s - 7ms/step - AUC: 0.9883 - loss: 0.2490 - val_AUC: 0.9800 - val_loss: 0.2880 - learning_rate: 0.0050
# Epoch 31/100
# 94/94 - 0s - 4ms/step - AUC: 0.9874 - loss: 0.2511 - val_AUC: 0.9849 - val_loss: 0.2628 - learning_rate: 0.0050
# Epoch 32/100
# 94/94 - 1s - 7ms/step - AUC: 0.9865 - loss: 0.2556 - val_AUC: 0.9829 - val_loss: 0.2719 - learning_rate: 0.0050
# Epoch 33/100
# 94/94 - 1s - 8ms/step - AUC: 0.9921 - loss: 0.2172 - val_AUC: 0.9835 - val_loss: 0.2526 - learning_rate: 0.0025
# Epoch 34/100
# 94/94 - 0s - 5ms/step - AUC: 0.9942 - loss: 0.1926 - val_AUC: 0.9879 - val_loss: 0.2296 - learning_rate: 0.0025
# Epoch 35/100
# 94/94 - 1s - 6ms/step - AUC: 0.9941 - loss: 0.1926 - val_AUC: 0.9884 - val_loss: 0.2123 - learning_rate: 0.0025
# Epoch 36/100
# 94/94 - 1s - 6ms/step - AUC: 0.9946 - loss: 0.1811 - val_AUC: 0.9884 - val_loss: 0.2070 - learning_rate: 0.0025
# Epoch 37/100
# 94/94 - 1s - 6ms/step - AUC: 0.9945 - loss: 0.1808 - val_AUC: 0.9890 - val_loss: 0.2094 - learning_rate: 0.0025
# Epoch 38/100
# 94/94 - 0s - 5ms/step - AUC: 0.9948 - loss: 0.1777 - val_AUC: 0.9872 - val_loss: 0.2391 - learning_rate: 0.0025
# Epoch 39/100
# 94/94 - 0s - 4ms/step - AUC: 0.9948 - loss: 0.1730 - val_AUC: 0.9898 - val_loss: 0.2280 - learning_rate: 0.0025
# Epoch 40/100
# 94/94 - 0s - 4ms/step - AUC: 0.9950 - loss: 0.1732 - val_AUC: 0.9902 - val_loss: 0.2056 - learning_rate: 0.0025
# Epoch 41/100
# 94/94 - 0s - 4ms/step - AUC: 0.9953 - loss: 0.1677 - val_AUC: 0.9850 - val_loss: 0.2198 - learning_rate: 0.0025
# Epoch 42/100
# 94/94 - 1s - 7ms/step - AUC: 0.9945 - loss: 0.1730 - val_AUC: 0.9898 - val_loss: 0.2035 - learning_rate: 0.0025
# Epoch 43/100
# 94/94 - 0s - 4ms/step - AUC: 0.9956 - loss: 0.1638 - val_AUC: 0.9895 - val_loss: 0.2036 - learning_rate: 0.0025
# Epoch 44/100
# 94/94 - 0s - 4ms/step - AUC: 0.9950 - loss: 0.1663 - val_AUC: 0.9870 - val_loss: 0.2007 - learning_rate: 0.0025
# Epoch 45/100
# 94/94 - 1s - 6ms/step - AUC: 0.9960 - loss: 0.1575 - val_AUC: 0.9884 - val_loss: 0.2082 - learning_rate: 0.0025
# Epoch 46/100
# 94/94 - 0s - 4ms/step - AUC: 0.9947 - loss: 0.1637 - val_AUC: 0.9882 - val_loss: 0.2017 - learning_rate: 0.0025
# Epoch 47/100
# 94/94 - 0s - 4ms/step - AUC: 0.9958 - loss: 0.1552 - val_AUC: 0.9898 - val_loss: 0.1939 - learning_rate: 0.0025
# Epoch 48/100
# 94/94 - 0s - 4ms/step - AUC: 0.9958 - loss: 0.1517 - val_AUC: 0.9908 - val_loss: 0.1870 - learning_rate: 0.0025
# Epoch 49/100
# 94/94 - 1s - 7ms/step - AUC: 0.9951 - loss: 0.1573 - val_AUC: 0.9889 - val_loss: 0.2018 - learning_rate: 0.0025
# Epoch 50/100
# 94/94 - 1s - 7ms/step - AUC: 0.9957 - loss: 0.1554 - val_AUC: 0.9866 - val_loss: 0.1989 - learning_rate: 0.0025
# Epoch 51/100
# 94/94 - 1s - 6ms/step - AUC: 0.9962 - loss: 0.1501 - val_AUC: 0.9881 - val_loss: 0.1907 - learning_rate: 0.0025
# Epoch 52/100
# 94/94 - 1s - 7ms/step - AUC: 0.9960 - loss: 0.1498 - val_AUC: 0.9916 - val_loss: 0.1855 - learning_rate: 0.0025
# Epoch 53/100
# 94/94 - 0s - 4ms/step - AUC: 0.9960 - loss: 0.1472 - val_AUC: 0.9906 - val_loss: 0.1957 - learning_rate: 0.0025
# Epoch 54/100
# 94/94 - 1s - 7ms/step - AUC: 0.9961 - loss: 0.1493 - val_AUC: 0.9905 - val_loss: 0.1733 - learning_rate: 0.0025
# Epoch 55/100
# 94/94 - 1s - 6ms/step - AUC: 0.9958 - loss: 0.1538 - val_AUC: 0.9840 - val_loss: 0.2176 - learning_rate: 0.0025
# Epoch 56/100
# 94/94 - 1s - 7ms/step - AUC: 0.9954 - loss: 0.1531 - val_AUC: 0.9874 - val_loss: 0.1966 - learning_rate: 0.0025
# Epoch 57/100
# 94/94 - 1s - 8ms/step - AUC: 0.9959 - loss: 0.1477 - val_AUC: 0.9868 - val_loss: 0.1978 - learning_rate: 0.0025
# Epoch 58/100
# 94/94 - 1s - 6ms/step - AUC: 0.9971 - loss: 0.1386 - val_AUC: 0.9876 - val_loss: 0.1933 - learning_rate: 0.0025
# Epoch 59/100
# 94/94 - 1s - 6ms/step - AUC: 0.9971 - loss: 0.1334 - val_AUC: 0.9917 - val_loss: 0.1762 - learning_rate: 0.0025
# Epoch 60/100
# 94/94 - 0s - 5ms/step - AUC: 0.9976 - loss: 0.1289 - val_AUC: 0.9911 - val_loss: 0.1871 - learning_rate: 0.0012
# Epoch 61/100
# 94/94 - 1s - 8ms/step - AUC: 0.9974 - loss: 0.1275 - val_AUC: 0.9891 - val_loss: 0.1809 - learning_rate: 0.0012
# Epoch 62/100
# 94/94 - 0s - 4ms/step - AUC: 0.9983 - loss: 0.1163 - val_AUC: 0.9924 - val_loss: 0.1787 - learning_rate: 0.0012
# Epoch 63/100
# 94/94 - 0s - 4ms/step - AUC: 0.9983 - loss: 0.1149 - val_AUC: 0.9923 - val_loss: 0.1708 - learning_rate: 0.0012
# Epoch 64/100
# 94/94 - 1s - 6ms/step - AUC: 0.9986 - loss: 0.1102 - val_AUC: 0.9910 - val_loss: 0.1594 - learning_rate: 0.0012
# Epoch 65/100
# 94/94 - 0s - 4ms/step - AUC: 0.9986 - loss: 0.1059 - val_AUC: 0.9917 - val_loss: 0.1647 - learning_rate: 0.0012
# Epoch 66/100
# 94/94 - 1s - 8ms/step - AUC: 0.9984 - loss: 0.1063 - val_AUC: 0.9911 - val_loss: 0.1574 - learning_rate: 0.0012
# Epoch 67/100
# 94/94 - 0s - 4ms/step - AUC: 0.9974 - loss: 0.1178 - val_AUC: 0.9912 - val_loss: 0.1683 - learning_rate: 0.0012
# Epoch 68/100
# 94/94 - 0s - 5ms/step - AUC: 0.9985 - loss: 0.1063 - val_AUC: 0.9921 - val_loss: 0.1629 - learning_rate: 0.0012
# Epoch 69/100
# 94/94 - 0s - 4ms/step - AUC: 0.9979 - loss: 0.1105 - val_AUC: 0.9907 - val_loss: 0.1767 - learning_rate: 0.0012
# Epoch 70/100
# 94/94 - 0s - 4ms/step - AUC: 0.9974 - loss: 0.1211 - val_AUC: 0.9898 - val_loss: 0.1639 - learning_rate: 0.0012
# Epoch 71/100
# 94/94 - 0s - 4ms/step - AUC: 0.9989 - loss: 0.0999 - val_AUC: 0.9910 - val_loss: 0.1759 - learning_rate: 0.0012
# Epoch 72/100
# 94/94 - 0s - 4ms/step - AUC: 0.9988 - loss: 0.0993 - val_AUC: 0.9921 - val_loss: 0.1626 - learning_rate: 6.2500e-04
# Epoch 73/100
# 94/94 - 1s - 6ms/step - AUC: 0.9989 - loss: 0.0965 - val_AUC: 0.9918 - val_loss: 0.1666 - learning_rate: 6.2500e-04
# Epoch 74/100
# 94/94 - 0s - 4ms/step - AUC: 0.9992 - loss: 0.0901 - val_AUC: 0.9918 - val_loss: 0.1588 - learning_rate: 6.2500e-04
# Epoch 75/100
# 94/94 - 0s - 4ms/step - AUC: 0.9992 - loss: 0.0893 - val_AUC: 0.9909 - val_loss: 0.1537 - learning_rate: 6.2500e-04
# Epoch 76/100
# 94/94 - 1s - 7ms/step - AUC: 0.9990 - loss: 0.0916 - val_AUC: 0.9917 - val_loss: 0.1500 - learning_rate: 6.2500e-04
# Epoch 77/100
# 94/94 - 1s - 6ms/step - AUC: 0.9991 - loss: 0.0882 - val_AUC: 0.9910 - val_loss: 0.1610 - learning_rate: 6.2500e-04
# Epoch 78/100
# 94/94 - 1s - 7ms/step - AUC: 0.9993 - loss: 0.0864 - val_AUC: 0.9919 - val_loss: 0.1535 - learning_rate: 6.2500e-04
# Epoch 79/100
# 94/94 - 0s - 4ms/step - AUC: 0.9993 - loss: 0.0853 - val_AUC: 0.9911 - val_loss: 0.1560 - learning_rate: 6.2500e-04
# Epoch 80/100
# 94/94 - 1s - 7ms/step - AUC: 0.9994 - loss: 0.0840 - val_AUC: 0.9918 - val_loss: 0.1604 - learning_rate: 6.2500e-04
# Epoch 81/100
# 94/94 - 0s - 4ms/step - AUC: 0.9993 - loss: 0.0872 - val_AUC: 0.9913 - val_loss: 0.1480 - learning_rate: 6.2500e-04
# Epoch 82/100
# 94/94 - 1s - 8ms/step - AUC: 0.9994 - loss: 0.0830 - val_AUC: 0.9919 - val_loss: 0.1523 - learning_rate: 6.2500e-04
# Epoch 83/100
# 94/94 - 1s - 6ms/step - AUC: 0.9992 - loss: 0.0838 - val_AUC: 0.9906 - val_loss: 0.1557 - learning_rate: 6.2500e-04
# Epoch 84/100
# 94/94 - 1s - 6ms/step - AUC: 0.9992 - loss: 0.0818 - val_AUC: 0.9917 - val_loss: 0.1526 - learning_rate: 6.2500e-04
# Epoch 85/100
# 94/94 - 1s - 5ms/step - AUC: 0.9995 - loss: 0.0786 - val_AUC: 0.9920 - val_loss: 0.1616 - learning_rate: 6.2500e-04
# Epoch 86/100
# 94/94 - 1s - 7ms/step - AUC: 0.9995 - loss: 0.0782 - val_AUC: 0.9906 - val_loss: 0.1616 - learning_rate: 6.2500e-04
# Epoch 87/100
# 94/94 - 0s - 5ms/step - AUC: 0.9993 - loss: 0.0811 - val_AUC: 0.9917 - val_loss: 0.1539 - learning_rate: 3.1250e-04
# Epoch 88/100
# 94/94 - 0s - 4ms/step - AUC: 0.9995 - loss: 0.0758 - val_AUC: 0.9923 - val_loss: 0.1518 - learning_rate: 3.1250e-04
# Epoch 89/100
# 94/94 - 1s - 6ms/step - AUC: 0.9994 - loss: 0.0779 - val_AUC: 0.9922 - val_loss: 0.1510 - learning_rate: 3.1250e-04
# Epoch 90/100
# 94/94 - 1s - 7ms/step - AUC: 0.9993 - loss: 0.0782 - val_AUC: 0.9929 - val_loss: 0.1414 - learning_rate: 3.1250e-04
# Epoch 91/100
# 94/94 - 0s - 4ms/step - AUC: 0.9992 - loss: 0.0782 - val_AUC: 0.9932 - val_loss: 0.1445 - learning_rate: 3.1250e-04
# Epoch 92/100
# 94/94 - 0s - 4ms/step - AUC: 0.9994 - loss: 0.0752 - val_AUC: 0.9922 - val_loss: 0.1421 - learning_rate: 3.1250e-04
# Epoch 93/100
# 94/94 - 1s - 6ms/step - AUC: 0.9995 - loss: 0.0731 - val_AUC: 0.9922 - val_loss: 0.1517 - learning_rate: 3.1250e-04
# Epoch 94/100
# 94/94 - 0s - 3ms/step - AUC: 0.9994 - loss: 0.0731 - val_AUC: 0.9929 - val_loss: 0.1503 - learning_rate: 3.1250e-04
# Epoch 95/100
# 94/94 - 0s - 4ms/step - AUC: 0.9996 - loss: 0.0722 - val_AUC: 0.9921 - val_loss: 0.1555 - learning_rate: 3.1250e-04
# Epoch 96/100
# 94/94 - 1s - 6ms/step - AUC: 0.9995 - loss: 0.0698 - val_AUC: 0.9930 - val_loss: 0.1492 - learning_rate: 1.5625e-04
# Epoch 97/100
# 94/94 - 1s - 6ms/step - AUC: 0.9996 - loss: 0.0694 - val_AUC: 0.9928 - val_loss: 0.1493 - learning_rate: 1.5625e-04
# Epoch 98/100
# 94/94 - 0s - 4ms/step - AUC: 0.9996 - loss: 0.0717 - val_AUC: 0.9930 - val_loss: 0.1455 - learning_rate: 1.5625e-04
# Epoch 99/100
# 94/94 - 0s - 4ms/step - AUC: 0.9996 - loss: 0.0704 - val_AUC: 0.9930 - val_loss: 0.1416 - learning_rate: 1.5625e-04
# Epoch 100/100
# 94/94 - 0s - 4ms/step - AUC: 0.9997 - loss: 0.0686 - val_AUC: 0.9932 - val_loss: 0.1429 - learning_rate: 1.5625e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# NR.AhR: Test AUC = 0.879
#
# Training on assay: NR.AR
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 116/116 - 10s - 85ms/step - AUC: 0.8689 - loss: 0.5491 - val_AUC: 0.9250 - val_loss: 0.5261 - learning_rate: 0.0100
# Epoch 2/100
# 116/116 - 3s - 24ms/step - AUC: 0.9361 - loss: 0.4037 - val_AUC: 0.9417 - val_loss: 0.4593 - learning_rate: 0.0100
# Epoch 3/100
# 116/116 - 1s - 5ms/step - AUC: 0.9560 - loss: 0.3618 - val_AUC: 0.9652 - val_loss: 0.4050 - learning_rate: 0.0100
# Epoch 4/100
# 116/116 - 1s - 5ms/step - AUC: 0.9688 - loss: 0.3285 - val_AUC: 0.9798 - val_loss: 0.3108 - learning_rate: 0.0100
# Epoch 5/100
# 116/116 - 0s - 3ms/step - AUC: 0.9745 - loss: 0.3141 - val_AUC: 0.9825 - val_loss: 0.2881 - learning_rate: 0.0100
# Epoch 6/100
# 116/116 - 1s - 5ms/step - AUC: 0.9784 - loss: 0.3035 - val_AUC: 0.9821 - val_loss: 0.2945 - learning_rate: 0.0100
# Epoch 7/100
# 116/116 - 1s - 7ms/step - AUC: 0.9801 - loss: 0.3018 - val_AUC: 0.9861 - val_loss: 0.2888 - learning_rate: 0.0100
# Epoch 8/100
# 116/116 - 1s - 5ms/step - AUC: 0.9818 - loss: 0.2946 - val_AUC: 0.9867 - val_loss: 0.2824 - learning_rate: 0.0100
# Epoch 9/100
# 116/116 - 1s - 5ms/step - AUC: 0.9832 - loss: 0.2915 - val_AUC: 0.9808 - val_loss: 0.3083 - learning_rate: 0.0100
# Epoch 10/100
# 116/116 - 1s - 5ms/step - AUC: 0.9834 - loss: 0.2903 - val_AUC: 0.9869 - val_loss: 0.2658 - learning_rate: 0.0100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# NR.AR: Test AUC = 0.818
#
# Training on assay: NR.AR.LBD
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 107/107 - 10s - 89ms/step - AUC: 0.8989 - loss: 0.5326 - val_AUC: 0.9435 - val_loss: 0.4775 - learning_rate: 0.0100
# Epoch 2/100
# 107/107 - 3s - 27ms/step - AUC: 0.9699 - loss: 0.3090 - val_AUC: 0.9916 - val_loss: 0.2518 - learning_rate: 0.0100
# Epoch 3/100
# 107/107 - 1s - 6ms/step - AUC: 0.9829 - loss: 0.2579 - val_AUC: 0.9954 - val_loss: 0.2247 - learning_rate: 0.0100
# Epoch 4/100
# 107/107 - 1s - 6ms/step - AUC: 0.9871 - loss: 0.2402 - val_AUC: 0.9915 - val_loss: 0.2205 - learning_rate: 0.0100
# Epoch 5/100
# 107/107 - 1s - 6ms/step - AUC: 0.9882 - loss: 0.2371 - val_AUC: 0.9940 - val_loss: 0.2174 - learning_rate: 0.0100
# Epoch 6/100
# 107/107 - 1s - 6ms/step - AUC: 0.9910 - loss: 0.2188 - val_AUC: 0.9926 - val_loss: 0.2292 - learning_rate: 0.0100
# Epoch 7/100
# 107/107 - 0s - 4ms/step - AUC: 0.9918 - loss: 0.2120 - val_AUC: 0.9968 - val_loss: 0.1800 - learning_rate: 0.0100
# Epoch 8/100
# 107/107 - 1s - 6ms/step - AUC: 0.9924 - loss: 0.2121 - val_AUC: 0.9965 - val_loss: 0.1852 - learning_rate: 0.0100
# Epoch 9/100
# 107/107 - 1s - 6ms/step - AUC: 0.9927 - loss: 0.2121 - val_AUC: 0.9970 - val_loss: 0.1715 - learning_rate: 0.0100
# Epoch 10/100
# 107/107 - 1s - 6ms/step - AUC: 0.9927 - loss: 0.2120 - val_AUC: 0.9957 - val_loss: 0.1907 - learning_rate: 0.0100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# NR.AR.LBD: Test AUC = 0.758
#
# Training on assay: NR.Aromatase
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 89/89 - 10s - 109ms/step - AUC: 0.8408 - loss: 0.6785 - val_AUC: 0.9246 - val_loss: 0.4428 - learning_rate: 0.0100
# Epoch 2/100
# 89/89 - 0s - 4ms/step - AUC: 0.9308 - loss: 0.4231 - val_AUC: 0.9458 - val_loss: 0.4012 - learning_rate: 0.0100
# Epoch 3/100
# 89/89 - 0s - 4ms/step - AUC: 0.9531 - loss: 0.3685 - val_AUC: 0.9545 - val_loss: 0.3875 - learning_rate: 0.0100
# Epoch 4/100
# 89/89 - 0s - 4ms/step - AUC: 0.9660 - loss: 0.3318 - val_AUC: 0.9790 - val_loss: 0.2907 - learning_rate: 0.0100
# Epoch 5/100
# 89/89 - 1s - 7ms/step - AUC: 0.9729 - loss: 0.3157 - val_AUC: 0.9811 - val_loss: 0.3135 - learning_rate: 0.0100
# Epoch 6/100
# 89/89 - 1s - 7ms/step - AUC: 0.9775 - loss: 0.3029 - val_AUC: 0.9831 - val_loss: 0.2727 - learning_rate: 0.0100
# Epoch 7/100
# 89/89 - 0s - 4ms/step - AUC: 0.9808 - loss: 0.2906 - val_AUC: 0.9864 - val_loss: 0.2716 - learning_rate: 0.0100
# Epoch 8/100
# 89/89 - 1s - 7ms/step - AUC: 0.9835 - loss: 0.2841 - val_AUC: 0.9815 - val_loss: 0.2950 - learning_rate: 0.0100
# Epoch 9/100
# 89/89 - 0s - 4ms/step - AUC: 0.9840 - loss: 0.2849 - val_AUC: 0.9781 - val_loss: 0.3182 - learning_rate: 0.0100
# Epoch 10/100
# 89/89 - 0s - 4ms/step - AUC: 0.9835 - loss: 0.2911 - val_AUC: 0.9894 - val_loss: 0.2575 - learning_rate: 0.0100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# NR.Aromatase: Test AUC = 0.771
#
# Training on assay: NR.ER
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 88/88 - 9s - 104ms/step - AUC: 0.7386 - loss: 0.7464 - val_AUC: 0.7882 - val_loss: 0.6972 - learning_rate: 0.0100
# Epoch 2/100
# 88/88 - 4s - 49ms/step - AUC: 0.8076 - loss: 0.6126 - val_AUC: 0.8132 - val_loss: 0.6259 - learning_rate: 0.0100
# Epoch 3/100
# 88/88 - 1s - 6ms/step - AUC: 0.8349 - loss: 0.5809 - val_AUC: 0.8641 - val_loss: 0.5477 - learning_rate: 0.0100
# Epoch 4/100
# 88/88 - 1s - 8ms/step - AUC: 0.8629 - loss: 0.5464 - val_AUC: 0.8740 - val_loss: 0.5451 - learning_rate: 0.0100
# Epoch 5/100
# 88/88 - 1s - 6ms/step - AUC: 0.8767 - loss: 0.5337 - val_AUC: 0.8668 - val_loss: 0.5752 - learning_rate: 0.0100
# Epoch 6/100
# 88/88 - 0s - 5ms/step - AUC: 0.8895 - loss: 0.5215 - val_AUC: 0.8897 - val_loss: 0.5380 - learning_rate: 0.0100
# Epoch 7/100
# 88/88 - 0s - 4ms/step - AUC: 0.8952 - loss: 0.5222 - val_AUC: 0.8991 - val_loss: 0.5386 - learning_rate: 0.0100
# Epoch 8/100
# 88/88 - 1s - 7ms/step - AUC: 0.9019 - loss: 0.5193 - val_AUC: 0.9070 - val_loss: 0.5214 - learning_rate: 0.0100
# Epoch 9/100
# 88/88 - 0s - 4ms/step - AUC: 0.9074 - loss: 0.5153 - val_AUC: 0.9011 - val_loss: 0.5349 - learning_rate: 0.0100
# Epoch 10/100
# 88/88 - 1s - 7ms/step - AUC: 0.9143 - loss: 0.5072 - val_AUC: 0.8943 - val_loss: 0.5669 - learning_rate: 0.0100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# NR.ER: Test AUC = 0.749
#
# Training on assay: NR.ER.LBD
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 108/108 - 10s - 90ms/step - AUC: 0.8481 - loss: 0.6373 - val_AUC: 0.9208 - val_loss: 0.4735 - learning_rate: 0.0100
# Epoch 2/100
# 108/108 - 3s - 25ms/step - AUC: 0.9356 - loss: 0.4119 - val_AUC: 0.9548 - val_loss: 0.4064 - learning_rate: 0.0100
# Epoch 3/100
# 108/108 - 1s - 5ms/step - AUC: 0.9585 - loss: 0.3557 - val_AUC: 0.9731 - val_loss: 0.3863 - learning_rate: 0.0100
# Epoch 4/100
# 108/108 - 0s - 4ms/step - AUC: 0.9669 - loss: 0.3353 - val_AUC: 0.9683 - val_loss: 0.3503 - learning_rate: 0.0100
# Epoch 5/100
# 108/108 - 0s - 4ms/step - AUC: 0.9731 - loss: 0.3160 - val_AUC: 0.9831 - val_loss: 0.2822 - learning_rate: 0.0100
# Epoch 6/100
# 108/108 - 0s - 4ms/step - AUC: 0.9787 - loss: 0.2990 - val_AUC: 0.9850 - val_loss: 0.2839 - learning_rate: 0.0100
# Epoch 7/100
# 108/108 - 0s - 4ms/step - AUC: 0.9792 - loss: 0.3045 - val_AUC: 0.9470 - val_loss: 0.4944 - learning_rate: 0.0100
# Epoch 8/100
# 108/108 - 0s - 4ms/step - AUC: 0.9814 - loss: 0.2967 - val_AUC: 0.9838 - val_loss: 0.2979 - learning_rate: 0.0100
# Epoch 9/100
# 108/108 - 0s - 4ms/step - AUC: 0.9835 - loss: 0.2886 - val_AUC: 0.9871 - val_loss: 0.2784 - learning_rate: 0.0100
# Epoch 10/100
# 108/108 - 0s - 4ms/step - AUC: 0.9829 - loss: 0.2943 - val_AUC: 0.9902 - val_loss: 0.2591 - learning_rate: 0.0100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# NR.ER.LBD: Test AUC = 0.761
#
# Training on assay: NR.PPAR.gamma
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 103/103 - 10s - 93ms/step - AUC: 0.8618 - loss: 0.6226 - val_AUC: 0.9667 - val_loss: 0.3359 - learning_rate: 0.0100
# Epoch 2/100
# 103/103 - 0s - 4ms/step - AUC: 0.9702 - loss: 0.3094 - val_AUC: 0.9890 - val_loss: 0.2666 - learning_rate: 0.0100
# Epoch 3/100
# 103/103 - 1s - 6ms/step - AUC: 0.9851 - loss: 0.2524 - val_AUC: 0.9929 - val_loss: 0.2069 - learning_rate: 0.0100
# Epoch 4/100
# 103/103 - 1s - 6ms/step - AUC: 0.9894 - loss: 0.2295 - val_AUC: 0.9955 - val_loss: 0.1904 - learning_rate: 0.0100
# Epoch 5/100
# 103/103 - 1s - 6ms/step - AUC: 0.9908 - loss: 0.2243 - val_AUC: 0.9950 - val_loss: 0.2094 - learning_rate: 0.0100
# Epoch 6/100
# 103/103 - 1s - 6ms/step - AUC: 0.9920 - loss: 0.2179 - val_AUC: 0.9885 - val_loss: 0.2412 - learning_rate: 0.0100
# Epoch 7/100
# 103/103 - 1s - 6ms/step - AUC: 0.9926 - loss: 0.2191 - val_AUC: 0.9899 - val_loss: 0.2493 - learning_rate: 0.0100
# Epoch 8/100
# 103/103 - 0s - 4ms/step - AUC: 0.9937 - loss: 0.2086 - val_AUC: 0.9954 - val_loss: 0.1995 - learning_rate: 0.0100
# Epoch 9/100
# 103/103 - 1s - 6ms/step - AUC: 0.9947 - loss: 0.2051 - val_AUC: 0.9952 - val_loss: 0.2078 - learning_rate: 0.0100
# Epoch 10/100
# 103/103 - 1s - 6ms/step - AUC: 0.9966 - loss: 0.1826 - val_AUC: 0.9940 - val_loss: 0.1994 - learning_rate: 0.0050
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# NR.PPAR.gamma: Test AUC = 0.822
#
# Training on assay: SR.ARE
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 79/79 - 9s - 111ms/step - AUC: 0.7400 - loss: 0.7576 - val_AUC: 0.8293 - val_loss: 0.6726 - learning_rate: 0.0100
# Epoch 2/100
# 79/79 - 0s - 4ms/step - AUC: 0.8380 - loss: 0.5897 - val_AUC: 0.8492 - val_loss: 0.6134 - learning_rate: 0.0100
# Epoch 3/100
# 79/79 - 0s - 4ms/step - AUC: 0.8730 - loss: 0.5378 - val_AUC: 0.8928 - val_loss: 0.5195 - learning_rate: 0.0100
# Epoch 4/100
# 79/79 - 0s - 4ms/step - AUC: 0.8938 - loss: 0.5012 - val_AUC: 0.9062 - val_loss: 0.5054 - learning_rate: 0.0100
# Epoch 5/100
# 79/79 - 1s - 8ms/step - AUC: 0.9090 - loss: 0.4788 - val_AUC: 0.9033 - val_loss: 0.5392 - learning_rate: 0.0100
# Epoch 6/100
# 79/79 - 0s - 4ms/step - AUC: 0.9187 - loss: 0.4681 - val_AUC: 0.9025 - val_loss: 0.5291 - learning_rate: 0.0100
# Epoch 7/100
# 79/79 - 0s - 4ms/step - AUC: 0.9245 - loss: 0.4652 - val_AUC: 0.9232 - val_loss: 0.4742 - learning_rate: 0.0100
# Epoch 8/100
# 79/79 - 0s - 4ms/step - AUC: 0.9280 - loss: 0.4654 - val_AUC: 0.9235 - val_loss: 0.4804 - learning_rate: 0.0100
# Epoch 9/100
# 79/79 - 0s - 4ms/step - AUC: 0.9328 - loss: 0.4575 - val_AUC: 0.9344 - val_loss: 0.4605 - learning_rate: 0.0100
# Epoch 10/100
# 79/79 - 0s - 4ms/step - AUC: 0.9349 - loss: 0.4590 - val_AUC: 0.9266 - val_loss: 0.5476 - learning_rate: 0.0100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# SR.ARE: Test AUC = 0.755
#
# Training on assay: SR.ATAD5
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 113/113 - 9s - 80ms/step - AUC: 0.8547 - loss: 0.6322 - val_AUC: 0.9553 - val_loss: 0.3784 - learning_rate: 0.0100
# Epoch 2/100
# 113/113 - 4s - 39ms/step - AUC: 0.9626 - loss: 0.3410 - val_AUC: 0.9705 - val_loss: 0.3140 - learning_rate: 0.0100
# Epoch 3/100
# 113/113 - 1s - 5ms/step - AUC: 0.9783 - loss: 0.2861 - val_AUC: 0.9849 - val_loss: 0.2770 - learning_rate: 0.0100
# Epoch 4/100
# 113/113 - 0s - 4ms/step - AUC: 0.9817 - loss: 0.2821 - val_AUC: 0.9859 - val_loss: 0.2704 - learning_rate: 0.0100
# Epoch 5/100
# 113/113 - 1s - 5ms/step - AUC: 0.9854 - loss: 0.2702 - val_AUC: 0.9886 - val_loss: 0.2460 - learning_rate: 0.0100
# Epoch 6/100
# 113/113 - 0s - 4ms/step - AUC: 0.9873 - loss: 0.2627 - val_AUC: 0.9875 - val_loss: 0.2500 - learning_rate: 0.0100
# Epoch 7/100
# 113/113 - 0s - 4ms/step - AUC: 0.9861 - loss: 0.2727 - val_AUC: 0.9825 - val_loss: 0.3125 - learning_rate: 0.0100
# Epoch 8/100
# 113/113 - 0s - 3ms/step - AUC: 0.9890 - loss: 0.2583 - val_AUC: 0.9896 - val_loss: 0.2479 - learning_rate: 0.0100
# Epoch 9/100
# 113/113 - 1s - 5ms/step - AUC: 0.9902 - loss: 0.2561 - val_AUC: 0.9866 - val_loss: 0.2841 - learning_rate: 0.0100
# Epoch 10/100
# 113/113 - 0s - 3ms/step - AUC: 0.9901 - loss: 0.2629 - val_AUC: 0.9838 - val_loss: 0.2969 - learning_rate: 0.0100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# SR.ATAD5: Test AUC = 0.815
#
# Training on assay: SR.HSE
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 100/100 - 9s - 93ms/step - AUC: 0.8090 - loss: 0.6656 - val_AUC: 0.9176 - val_loss: 0.4631 - learning_rate: 0.0100
# Epoch 2/100
# 100/100 - 0s - 4ms/step - AUC: 0.9122 - loss: 0.4729 - val_AUC: 0.9380 - val_loss: 0.4932 - learning_rate: 0.0100
# Epoch 3/100
# 100/100 - 0s - 4ms/step - AUC: 0.9418 - loss: 0.4122 - val_AUC: 0.9228 - val_loss: 0.5886 - learning_rate: 0.0100
# Epoch 4/100
# 100/100 - 0s - 4ms/step - AUC: 0.9579 - loss: 0.3745 - val_AUC: 0.9719 - val_loss: 0.3843 - learning_rate: 0.0100
# Epoch 5/100
# 100/100 - 0s - 3ms/step - AUC: 0.9652 - loss: 0.3616 - val_AUC: 0.9716 - val_loss: 0.3447 - learning_rate: 0.0100
# Epoch 6/100
# 100/100 - 1s - 6ms/step - AUC: 0.9708 - loss: 0.3482 - val_AUC: 0.9796 - val_loss: 0.3159 - learning_rate: 0.0100
# Epoch 7/100
# 100/100 - 0s - 3ms/step - AUC: 0.9714 - loss: 0.3501 - val_AUC: 0.9764 - val_loss: 0.3563 - learning_rate: 0.0100
# Epoch 8/100
# 100/100 - 0s - 4ms/step - AUC: 0.9740 - loss: 0.3468 - val_AUC: 0.9681 - val_loss: 0.4063 - learning_rate: 0.0100
# Epoch 9/100
# 100/100 - 1s - 6ms/step - AUC: 0.9769 - loss: 0.3372 - val_AUC: 0.9868 - val_loss: 0.3028 - learning_rate: 0.0100
# Epoch 10/100
# 100/100 - 0s - 3ms/step - AUC: 0.9775 - loss: 0.3419 - val_AUC: 0.9695 - val_loss: 0.3789 - learning_rate: 0.0100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# SR.HSE: Test AUC = 0.797
#
# Training on assay: SR.MMP
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 80/80 - 9s - 116ms/step - AUC: 0.8575 - loss: 0.6222 - val_AUC: 0.9239 - val_loss: 0.5154 - learning_rate: 0.0100
# Epoch 2/100
# 80/80 - 0s - 4ms/step - AUC: 0.9225 - loss: 0.4422 - val_AUC: 0.9482 - val_loss: 0.3815 - learning_rate: 0.0100
# Epoch 3/100
# 80/80 - 1s - 8ms/step - AUC: 0.9373 - loss: 0.4072 - val_AUC: 0.9585 - val_loss: 0.3485 - learning_rate: 0.0100
# Epoch 4/100
# 80/80 - 0s - 4ms/step - AUC: 0.9509 - loss: 0.3747 - val_AUC: 0.9572 - val_loss: 0.3662 - learning_rate: 0.0100
# Epoch 5/100
# 80/80 - 1s - 8ms/step - AUC: 0.9567 - loss: 0.3619 - val_AUC: 0.9580 - val_loss: 0.3605 - learning_rate: 0.0100
# Epoch 6/100
# 80/80 - 0s - 4ms/step - AUC: 0.9592 - loss: 0.3615 - val_AUC: 0.9650 - val_loss: 0.3561 - learning_rate: 0.0100
# Epoch 7/100
# 80/80 - 0s - 4ms/step - AUC: 0.9619 - loss: 0.3597 - val_AUC: 0.9688 - val_loss: 0.3475 - learning_rate: 0.0100
# Epoch 8/100
# 80/80 - 0s - 4ms/step - AUC: 0.9639 - loss: 0.3605 - val_AUC: 0.9663 - val_loss: 0.3524 - learning_rate: 0.0100
# Epoch 9/100
# 80/80 - 0s - 4ms/step - AUC: 0.9679 - loss: 0.3493 - val_AUC: 0.9669 - val_loss: 0.3583 - learning_rate: 0.0100
# Epoch 10/100
# 80/80 - 0s - 4ms/step - AUC: 0.9670 - loss: 0.3561 - val_AUC: 0.9692 - val_loss: 0.3520 - learning_rate: 0.0100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# SR.MMP: Test AUC = 0.896
#
# Training on assay: SR.p53
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 105/105 - 9s - 89ms/step - AUC: 0.7906 - loss: 0.7627 - val_AUC: 0.9101 - val_loss: 0.5160 - learning_rate: 0.0100
# Epoch 2/100
# 105/105 - 0s - 4ms/step - AUC: 0.9157 - loss: 0.4554 - val_AUC: 0.9144 - val_loss: 0.4739 - learning_rate: 0.0100
# Epoch 3/100
# 105/105 - 0s - 4ms/step - AUC: 0.9473 - loss: 0.3887 - val_AUC: 0.9381 - val_loss: 0.4188 - learning_rate: 0.0100
# Epoch 4/100
# 105/105 - 1s - 6ms/step - AUC: 0.9568 - loss: 0.3727 - val_AUC: 0.9763 - val_loss: 0.3085 - learning_rate: 0.0100
# Epoch 5/100
# 105/105 - 0s - 4ms/step - AUC: 0.9664 - loss: 0.3521 - val_AUC: 0.9746 - val_loss: 0.3570 - learning_rate: 0.0100
# Epoch 6/100
# 105/105 - 0s - 4ms/step - AUC: 0.9711 - loss: 0.3433 - val_AUC: 0.9679 - val_loss: 0.3623 - learning_rate: 0.0100
# Epoch 7/100
# 105/105 - 0s - 4ms/step - AUC: 0.9733 - loss: 0.3439 - val_AUC: 0.9750 - val_loss: 0.3469 - learning_rate: 0.0100
# Epoch 8/100
# 105/105 - 0s - 4ms/step - AUC: 0.9733 - loss: 0.3477 - val_AUC: 0.9759 - val_loss: 0.3630 - learning_rate: 0.0100
# Epoch 9/100
# 105/105 - 0s - 4ms/step - AUC: 0.9771 - loss: 0.3359 - val_AUC: 0.9793 - val_loss: 0.3304 - learning_rate: 0.0100
# Epoch 10/100
# 105/105 - 1s - 6ms/step - AUC: 0.9862 - loss: 0.2836 - val_AUC: 0.9897 - val_loss: 0.2529 - learning_rate: 0.0050
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# SR.p53: Test AUC = 0.793
#
# Average Test AUC: 0.801
